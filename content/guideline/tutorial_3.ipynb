# %% [markdown]
# # Tagging and naming
#
# Usually, for files and organization, we would have names and typical
# management templates to control how contents are structured and how to
# easily refer individual contents together. This is what we are intended
# to do, in this section itself.

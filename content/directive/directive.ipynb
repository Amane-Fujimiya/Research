# %% [markdown]
# # Directive
#
# The directive is simple as it is. Basically to statement, ado of
# thoughts and what to research, instead of simply leaving there the
# listing of all possible research in mind. Sometimes, you have to forgo
# of the listing, of the speculation, to step back and enjoy the taste of
# having what is to be introduced and understood. Such is to say, a
# *research paradigm*.
#
# ## Directive A
#
# The first directive would obviously be the formation phase of
# RHINELAB-RINALAB.

# %% [markdown]
# # Work bulletin
#
# Well, hello. I think we would have nothing much to say to each other at
# this point, though I doubt if that is what you are waiting of at the end
# of the road. Nevertheless, here, we go with the content preparations and
# thereof. Indeed of such, we have the *main* organization sections,
# containing projects, researches, projects, proposals, plans, and
# essentially works to be done. Those will be covered in a few of those
# sections.
#
# Then, we have the *directive* section, where ideas, proposals are laid
# out, research diagram or directive, plans and programme are laid out,
# alongside infrastructures and stuff that are necessary for research and
# further works. Then we also have *notes*, of which we defer its usage
# for all types of notes, expositions, drafts, important layout, points to
# be made across the structures, connectors, and so on. And finally, for
# those that does not fit, we simply use the *miscellaneous* section at
# will.
#
# For now, it is that way. Further purposes would be clarified later on,
# but essentially of such, we are current ready for any indictment in the
# future on the organization template.
#
# ## Organization
#
# As mentioned or dictated in [the preface](../..\publications.qmd), there
# exists three main parts of this site, alongside subsidiary delegations.
# The tagging organization will be included in [this
# note](../..\content/guideline/tutorial_3.qmd).
#
# ## Research
#
# The research page includes the list of projects, researches in
# questions, proposals and ideas that is of consideration in the future.
# Most of them are incomplete, and are welcoming adoption from certain
# collaboration if requested or encouraged. While this is not always
# up-to-date (as I have an internal organization structure), it should be,
# most of the time adequate at outlining individual ideas and rotational
# constructs relevant to the research agenda.
#
# The topic of research includes (2025/28/11): *theoretical computer
# science*, *theoretical machine learning*, *theoretical artificial
# intelligence*, *philosophy of science*, *spectroscopic theory*,
# *theoretical physics*, *high-energy physics*, *Raman spectroscopy*,
# *automata theory*, **probability theory**, *theory of modelling*,
# *statistical machine learning*, *abstract mathematics*, *applications of
# category theory*, *partial differential equation (PDE)*, *neural network
# formalism*, and *philosophy of probability*.
#
# ### Current research
#
# Currently, in production documents and manuscripts are listed as below.
#
# -   Neural network documentation (deep learning, documentation)
#     ([here](https://amane-fujimiya.github.io/ML_Aneurysm/)). Progress is
#     kind of slow, but is expected - estimate first completed revision
#     around March 2027. `PR01`
# -   Neuroscience documentation (knowledge base, neuroscience) project.
#     (Currently the website `html` template is having issues, so I am
#     putting that on hold for now). `PR02`
# -   Quantum physics blog (for now the website is in preparation, but
#     will use `Hugo` template, so I have to familiarize myself with it).
#     The main blog profiling is [This particular
#     page](../..\content/blog_quantum/main.qmd) - estimated completion by
#     the end of 2027. `PR03`
# -   Raman spectroscopy paper: **Raman spectroscopy and ML application on
#     yogurt** (organize in [this
#     sheet](https://docs.google.com/spreadsheets/d/1YEIsuMXNXF8oxPgoSBlZ7ugon3b_bcVWQIRicdyTPQk/edit?usp=sharing)) -
#     in production, estimate completion around November 2026. `RA01`
# -   A paper on **Quantum well analysis of nonlinear absorption
#     coefficient** - will have to explain this in a few separated
#     documents and thereof that is. Work alongside [Duong Ngoc
#     Khoa](https://www.linkedin.com/in/duong-khoa-a77592378/) - Estimated
#     completion by February 2026. `RA02`
# -   A paper about **Vibrational spectroscopy and Raman spectroscopic
#     theory - a review** with also *Duong Ngoc Khoa* and *Yogesh Verma*
#     (Xavier International College), where we attempt to identify the
#     main theme, historical contexts, theoretical baseline, different
#     interpretations, thresholds, limitations, paradoxes, weakness and
#     dilemma of the current theoretical structures. `RA03`
# -   A paper on **Hall effect in electromagnetic field induced quantum
#     well system** - Adapt from earlier researches from *Phung Huy Hieu*,
#     a new-graduated assistant researcher I know of. `RA04`
# -   A paper on **Quantum replica from PINNs** research, taken from a
#     previous small report that I am allowed to be used as provision and
#     foundation of in VNU. `RA05`
# -   Statistical learning theory paper, ‘**Double descent in theoretical
#     machine learning**’ and potential analysis on such. It is a
#     *landmark paper* in the sense of efforts poured in. Current main
#     manuscript is in private - estimated February 2026 for submission.
#     `RA06`
# -   A **main book** called **Theoretical Automata** and so on. The
#     repository for the book is already online in my `github` profile,
#     though it is arguably, well, less updated since there are a lot of
#     contents that I want it to just stay there. However, it is one of my
#     **main project**, as the philosophy, methodology, theory and so on
#     is all in there of my working choice. The page for such descriptions
#     (or anything else of it), is [here](../..\content/res/r_ta.qmd).
#     `RM00`
#
# Specific expansion and main papers are not included, as per
# categorization as non-trivial analysis. Those listed above are main
# commitments, and thus far would be well under way of constructions
# since, though again, not completely up-to-date.
#
# ### In preparation and completed researches
#
# In preparation works can be seen in the respective page in
# [here](../..\publications.qmd).
#
# Completed research includes:
#
# -   Paper on machine learning applications on Raman spectroscopy:
#     **Using Machine Learning For Quantitative Analysis of Raman Spectra
#     of Amino Acid Mixtures** - published in ICPA13. `RF01`
#
# -   Paper on Artificial Intelligence - **Foundations of Artificial
#     Intelligence Frameworks: Notion and Limits of AGI**, available on
#     [Arxiv Archive](https://arxiv.org/abs/2511.18517). We have a lot of
#     comments on it. `RF02`

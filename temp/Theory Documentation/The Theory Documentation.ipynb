# %% [markdown]
# #
#
# Main storage point for documentation releases. \## Argued questions -
# What is over-parameterized and under-parameterized model? How would that
# affect the model? - What is the analogue concept for non-parameterized
# models? - What is model complexity? How many **variations** are there?
# \_\_\_ \## Documents \### I. Mathematical Preliminary
#
# #### 1. Graph theory
#
# -   [MPA - Graph Theory I](MPA%20-%20Graph%20Theory%20I.md)
# -   [MPA - Graph Theory II](MPA%20-%20Graph%20Theory%20II.md)
# -   [MPA - Graph Representation
#     Algebra](MPA%20-%20Graph%20Representation%20Algebra.md)
#
# ### II. Core Knowledge
#
# -   [C1 - Graph Neural Networks](C1%20-%20Graph%20Neural%20Networks.md)
# -   [C2 - Concept Learning and
#     Inference](C2%20-%20Concept%20Learning%20and%20Inference.md)
#
# ### III. Concepts
#
# -   [D1 -
#     Over(under)-parameterization](D1%20-%20Over(under)-parameterization.md)
# -   [D2 - Rademacher Complexity](D2%20-%20Rademacher%20Complexity.md)
# -   [D3 - Generalized Regression Neural
#     Network](D3%20-%20Generalized%20Regression%20Neural%20Network.md)
# -   [D4 - Non-parameterization](D4%20-%20Non-parameterization.md)
# -   [D5 - Manifold Hypothesis](D5%20-%20Manifold%20Hypothesis.md)
# -   [D6 - Latent Space](D6%20-%20Latent%20Space.md)
# -   [D7 - Probability spaces and random
#     variables](D7%20-%20Probability%20spaces%20and%20random%20variables.md)
# -   [D8 - Permutation Invariance and
#     Equivariance](D8%20-%20Permutation%20Invariance%20and%20Equivariance.md)
# -   [D9 - Flattening Matrix](D9%20-%20Flattening%20Matrix.md)
#
# ### IV. Paper (ICML stuff)
#
# -   [Section 3IC - Formulating the
#     problem](Section%203IC%20-%20Formulating%20the%20problem.md)

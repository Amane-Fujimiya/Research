# %% [markdown]
# #
#
# A lightweight introduction to graph theory \[\[MPAA1 - Definitions of
# graph\]\] \[\[MPAA2 - Properties of Graph\]\] \[\[MPAA3 - Adjacency\]\]
# \[\[MPAA4 - Subgraphs\]\] \[\[MPAA5 - Handshaking Lemma\]\]
